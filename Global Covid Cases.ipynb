# %% [markdown]
# # Data Analysis of Global Covid Cases
# ### This notebook does a daily scrape of live data on global coronavirus case counts. This is an ongoing data and I haven't decided what to do with this data yet.
# #### Author: Khyatee Desai

# %%
import re
import csv
import json
from datetime import date
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Live data (https://www.worldometers.info/coronavirus) resets ~8pmEST.
# # Scrape live data - contains "today" and "yesterday" data.
# Last run: 4/18/2020 11:AM EST

# %%
# base_url = 'https://www.worldometers.info/coronavirus/#countries'
# r = requests.get(base_url)
# outfile = open(str(date.today()) + '.html', 'w')
# outfile.write(r.text)
# outfile.close()

# %% [markdown]
# ### Get Table Headers Once
# Create empty list and add headers to it

# %%
# html = open(str(date.today()) + '.html','r')
# soup = BeautifulSoup(html, "html.parser")
# table = soup.find(id='main_table_countries_today')
# headers = table.find('thead').find('tr')
# headers = headers.text.split('\n')
# headers[12] = 'Tests/1M pop'
# headers[13] = 'Continent'
# headers = headers[1:14]
# headers
# Out:
# ['Country,Other',
#  'TotalCases',
#  'NewCases',
#  'TotalDeaths',
#  'NewDeaths',
#  'TotalRecovered',
#  'ActiveCases',
#  'Serious,Critical',
#  'Tot\xa0Cases/1M pop',
#  'Deaths/1M pop',
#  'TotalTests',
#  'Tests/1M pop',
#  'Continent']

# %% [markdown]
# ### CURRENT Case Count
# Parses out daily cases for each country and creates list of lists "df"

# %%
to_df = []
to_df.append(headers)
base_url = 'https://www.worldometers.info/coronavirus/#countries'
r = requests.get(base_url)
soup = BeautifulSoup(r.text, "html.parser")
table = soup.find(id='main_table_countries_today')
countries = table.find('tbody').findAll('tr')
for country in countries[7:]:
    items=[]
    items = country.text.split('\n')
    to_df.append(items[1:])
current_cases_df = pd.DataFrame(to_df)
current_cases_df.head()
# Out:
#                0           1         2            3          4  \
# 0  Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths
# 1          World   2,223,240   +60,899      152,328     +6,857
# 2            USA     690,900   +13,330      35,955      +1,338
# 3          Spain     188,093    +3,145      19,613        +298
# 4          Italy     172,434    +3,493      22,745        +575
#
#                 5            6                 7                 8  \
# 0  TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 1         567,279    1,503,633            56,197               285
# 2          58,263      596,682            13,466             2,087
# 3          74,797       93,683             7,371             4,023
# 4          42,727      106,962             2,812             2,852
#
#                9          10            11             12    13
# 0  Deaths/1M pop  TotalTests  Tests/1M pop      Continent  None
# ...

# %% [markdown]
# ### Final Counts for April 12

# %%
to_df = []
to_df.append(headers)
html = open("2020-04-13" + '.html','r')
soup = BeautifulSoup(html, "html.parser")
table = soup.find(id='main_table_countries_yesterday')
countries = table.find('tbody').findAll('tr')
for country in countries[7:]:
    items=[]
    items = country.text.split('\n')
    to_df.append(items[1:])
apr12_df = pd.DataFrame(to_df)
apr12_df.head(10)
# Out:
#                0           1         2            3          4  \
# 0  Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths
# 1          World   1,852,365   +72,523      114,196     +5,417
# 2          China      82,160      +108       3,341          +2
# 3            USA     560,300   +27,421      22,105      +1,528
# 4          Spain     166,831    +3,804      17,209        +603
# 5          Italy     156,363    +4,092      19,899        +431
# 6         France     132,591    +2,937      14,393        +561
# 7        Germany     127,854    +2,402       3,022        +151
# 8             UK      84,279    +5,288      10,612        +737
# 9           Iran      71,686    +1,657       4,474        +117
#
#                 5            6                 7                 8  \
# 0  TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 1         423,399    1,314,770            50,758               238
# 2          77,663        1,156               121                57
# ...

# %% [markdown]
# ### Final Cases for April 13

# %%
to_df = []
to_df.append(headers)
html = open("2020-04-14" + '.html','r')
soup = BeautifulSoup(html, "html.parser")
table = soup.find(id='main_table_countries_yesterday')
countries = table.find('tbody').findAll('tr')
for country in countries[7:]:
    items=[]
    items = country.text.split('\n')
    to_df.append(items[1:])
apr13_df = pd.DataFrame(to_df)
apr13_df.head(10)
# Out:
#                0           1         2            3          4  \
# 0  Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths
# 1          World   1,923,848   +71,591      119,618     +5,423
# 2          China      82,160      +108       3,341          +2
# 3            USA     586,941   +26,641      23,640      +1,535
# 4          Spain     170,099    +3,268      17,756        +547
# 5          Italy     159,516    +3,153      20,465        +566
# 6         France     136,779    +4,188      14,967        +574
# 7        Germany     130,072    +2,218       3,194        +172
# 8             UK      88,621    +4,342      11,329        +717
# 9           Iran      73,303    +1,617       4,585        +111
#
#                 5            6                 7                 8  \
# 0  TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 1         444,636    1,359,594            51,747               247
# 2          77,663        1,156               121                57
# ...

# %% [markdown]
# ## Final Cases for April 14

# %%
to_df = []
to_df.append(headers)
html = open("2020-04-15" + '.html','r')
soup = BeautifulSoup(html, "html.parser")
table = soup.find(id='main_table_countries_yesterday')
countries = table.find('tbody').findAll('tr')
for country in countries[7:]:
    items=[]
    items = country.text.split('\n')
    to_df.append(items[1:])
apr14_df = pd.DataFrame(to_df)
apr14_df.head(10)
# Out:
#                0           1         2            3          4  \
# 0  Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths
# 1          World   1,997,860   +74,012      126,600     +6,982
# 2          China      82,249       +89       3,341
# 3            USA     613,886   +26,945      26,047      +2,407
# 4          Spain     174,060    +3,961      18,255        +499
# 5          Italy     162,488    +2,972      21,067        +602
# 6         France     143,303    +6,524      15,729        +762
# 7        Germany     132,210    +2,138       3,495        +301
# 8             UK      93,873    +5,252      12,107        +778
# 9           Iran      74,877    +1,574       4,683         +98
#
#                 5            6                 7                 8  \
# 0  TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 1         478,516    1,392,744            51,612               256
# 2          77,738        1,170               116                57
# ...

# %% [markdown]
# ## Final Cases for April 15

# %%
to_df = []
to_df.append(headers)
html = open("2020-04-15" + '.html','r')
soup = BeautifulSoup(html, "html.parser")
table = soup.find(id='main_table_countries_today')
countries = table.find('tbody').findAll('tr')
for country in countries[7:]:
    items=[]
    items = country.text.split('\n')
    to_df.append(items[1:])
apr15_df = pd.DataFrame(to_df)
apr15_df.head(10)
# Out:
#                0           1         2            3          4  \
# 0  Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths
# 1          World   2,049,849   +51,989      132,835     +6,235
# 2            USA     622,412    +8,526      27,549      +1,502
# 3          Spain     177,633    +3,573      18,579        +324
# 4          Italy     165,155    +2,667      21,645        +578
# 5         France     147,863    +4,560      17,167      +1,438
# 6        Germany     133,154      +944       3,592         +97
# 7             UK      98,476    +4,603      12,868        +761
# 8           Iran      76,389    +1,512       4,777         +94
# 9         Turkey      69,392    +4,281       1,518        +115
#
#                 5            6                 7                 8  \
# 0  TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 1         507,782    1,409,232            51,153               263
# 2          47,707      547,156            13,477             1,880
# ...

# %% [markdown]
# ## Final Cases for April 16

# %%
to_df = []
to_df.append(headers)
html = open("2020-04-17" + '.html','r')
soup = BeautifulSoup(html, "html.parser")
table = soup.find(id='main_table_countries_yesterday')
countries = table.find('tbody').findAll('tr')
for country in countries[7:]:
    items=[]
    items = country.text.split('\n')
    to_df.append(items[1:])
apr16_df = pd.DataFrame(to_df)
apr16_df.head(10)
# Out:
#                0           1         2            3          4  \
# 0  Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths
# 1          World   2,162,341   +90,274      145,471     +6,996
# 2          China      82,341       +46       3,342
# 3            USA     677,570   +29,567      34,617      +2,174
# 4          Spain     184,948    +4,289      19,315        +503
# 5          Italy     168,941    +3,786      22,170        +525
# 6         France     146,060   +12,416      17,920        +753
# 7        Germany     137,698    +2,945       4,052        +248
# 8             UK     103,093    +4,617      13,729        +861
# 9           Iran      77,995    +1,606       4,869         +92
#
#                 5            6                 7                 8  \
# 0  TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 1         547,069    1,469,801            56,602               277
# 2          77,892        1,107                95                57
# ...

# %% [markdown]
# ## Final cases for April 17

# %%
to_df = []
to_df.append(headers)
html = open("2020-04-18" + '.html','r')
soup = BeautifulSoup(html, "html.parser")
table = soup.find(id='main_table_countries_yesterday')
countries = table.find('tbody').findAll('tr')
for country in countries[7:]:
    items=[]
    items = country.text.split('\n')
    to_df.append(items[1:])
apr17_df = pd.DataFrame(to_df)
apr17_df.head(10)
# Out:
#                0           1         2            3          4  \
# 0  Country,Other  TotalCases  NewCases  TotalDeaths  NewDeaths
# 1          World   2,248,863   +86,496      154,145     +8,672
# 2          China      82,692      +325       4,632      +1,290
# 3            USA     709,735   +32,165      37,154      +2,535
# 4          Spain     190,839    +5,891      20,002        +687
# 5          Italy     172,434    +3,493      22,745        +575
# 6         France     147,969    +1,909      18,681        +761
# 7        Germany     141,397    +3,699       4,352        +300
# 8             UK     108,692    +5,599      14,576        +847
# 9           Iran      79,494    +1,499       4,958         +89
#
#                 5            6                 7                 8  \
# 0  TotalRecovered  ActiveCases  Serious,Critical  Tot Cases/1M pop
# 1         571,573    1,523,145            56,963               289
# 2          77,994           66                85                57
# ...

# %% [markdown]
# ======================================================================================================================

# %% [markdown]
# # Play with the Data
