# %% [markdown]
# # Coronavirus Testing in NYC by Zip Code
# ### This notebook explores the disparities of coronavirus testing across NYC zip codes
# #### Khyatee Desai<br>April 15, 2020

# %% [markdown]
# # Data Sets
# **1. Population by Zip Code:** http://www.usa.com/rank/new-york-northern-new-jersey-long-island-ny-nj-pa-area--population-density--zip-code-rank.htm?yr=9000&dis=&wist=&plow=&phigh=<br>
# **2. Testing by Zip Code:** https://github.com/nychealth/coronavirus-data<br>
# **3. NYC Zip Codes Shapefile** https://data.beta.nyc/dataset/nyc-zip-code-tabulation-areas

# %%
import re
import csv
import json
from datetime import date
import requests
from bs4 import BeautifulSoup
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np 
import geopandas as gpd
import mapclassify

# %% [markdown]
# ## Data Collection: Population within each Zip Code

# %%
# base_url = 'http://www.usa.com/rank/new-york-northern-new-jersey-long-island-ny-nj-pa-area--population-density--zip-code-rank.htm?yr=9000&dis=&wist=&plow=&phigh='
# r = requests.get(base_url)
# outfile = open('popDensity.html', 'w')
# outfile.write(r.text)
# outfile.close()

# %%
html = open('popDensity.html','r')
soup = BeautifulSoup(html, "html.parser")
rows = soup.findAll('tr')
to_df = []
for row in rows[2:]:
    columns = row.findAll('td')
    zipPop = columns[2].text
    to_df.append(zipPop.split(' / '))
zip_pop_df = pd.DataFrame(to_df)
zip_pop_df = zip_pop_df.rename(columns={0:'Zip', 1:"Population"})
zip_pop_df
# Out:
#        Zip Population
# 0    10028     46,169
# 1    10128     62,447
# 2    10075     24,377
# 3    10025     97,373
# 4    10023     60,762
# ..     ...        ...
# 878  11430        171
# 879  07851        106
# 880  11973         40
# 881  10911          2
# 882  07881          9
#
# [883 rows x 2 columns]

# %% [markdown]
# ## Data Collection: Number of covid tests within each zip code

# %%
test_df = pd.read_csv('test_data.csv')
test_df = test_df.rename(columns={'MODZCTA':'Zip', 'Total':"TotalTested","zcta_cum.perc_pos":"PercentTestedPos"})
test_df['Zip'] = test_df['Zip'].astype(str).str.split('.', expand = True)[0]
test_df
# Out:
#        Zip  Positive  TotalTested  PercentTestedPos
# 0      nan      1851         2017             91.77
# 1    10001       221          462             47.84
# 2    10002       554         1045             53.01
# 3    10003       285          678             42.04
# 4    10004        23           59             38.98
# ..     ...       ...          ...               ...
# 173  11691      1155         1715             67.35
# 174  11692       310          493             62.88
# 175  11693       205          347             59.08
# 176  11694       371          641             57.88
# 177  11697        63          132             47.73
#
# [178 rows x 4 columns]

# %% [markdown]
# ### Merge the datasets

# %%
merged = pd.merge(zip_pop_df, test_df, on='Zip')
merged['Population'] = merged['Population'].str.replace(',','').astype(int)
merged
# Out:
#        Zip  Population  Positive  TotalTested  PercentTestedPos
# 0    10028       46169       326          822             39.66
# 1    10128       62447       403         1027             39.24
# 2    10075       24377       265          571             46.41
# 3    10025       97373       652         1485             43.91
# 4    10023       60762       350          871             40.18
# ..     ...         ...       ...          ...               ...
# 172  10314       87524      1608         3329             48.30
# 173  10004        3024        23           59             38.98
# 174  10309       33382       575         1298             44.30
# 175  11697        4078        63          132             47.73
# 176  10464        4532        76          195             38.97
#
# [177 rows x 5 columns]

# %% [markdown]
# ### Add column for percent of population within zip code that has been tested

# %%
merged['PercentPopTested'] = ((merged['TotalTested']/merged['Population'])*100).round(2)
merged.sort_values('Population', ascending=False).head()
# Out:
#        Zip  Population  Positive  TotalTested  PercentTestedPos  \
# 78   11368      110385      2446         3102             78.85
# 50   11220      101715       808         1277             63.27
# 41   11373      100713      1893         2647             71.51
# 107  11385      100132      1091         1839             59.33
# 77   10467       99251      1818         2991             60.78
#
#      PercentPopTested
# 78               2.81
# 50               1.26
# 41               2.63
# 107              1.84
# 77               3.01

# %% [markdown]
# ### Visualize with heatmap

# %%
heat = merged[['Zip', 'PercentPopTested']]
heat.set_index('Zip', inplace=True)
sns.heatmap(heat.head(20), annot=True)

# %% [markdown]
# # Choropleth Map
# ### import shapefile for NYC zip codes and create GeoDataFrame with GeoPandas

# %%
shapefile = 'zips.shp'
#Read shapefile using Geopandas
gdf = gpd.read_file(shapefile)
gdf
# Out:
#      OBJECTID postalCode          PO_NAME STATE    borough ST_FIPS CTY_FIPS  \
# 0           1      11372  Jackson Heights    NY     Queens      36      081
# 1           2      11004        Glen Oaks    NY     Queens      36      081
# 2           3      11040    New Hyde Park    NY     Queens      36      081
# 3           4      11426        Bellerose    NY     Queens      36      081
# 4           5      11365    Fresh Meadows    NY     Queens      36      081
# ..        ...        ...              ...   ...        ...     ...      ...
# 257       258      10065         New York    NY  Manhattan      36      061
# 258       259      10075         New York    NY  Manhattan      36      061
# 259       260      10069         New York    NY  Manhattan      36      061
# 260       261      10281         New York    NY  Manhattan      36      061
# 261       262      10282         New York    NY  Manhattan      36      061
#
#      BLDGpostal                                                @id  longitude  \
# 0             0  http://nyc.pediacities.com/Resource/PostalCode... -73.883573
# 1             0  http://nyc.pediacities.com/Resource/PostalCode... -73.711608
# 2             0  http://nyc.pediacities.com/Resource/PostalCode... -73.703443
# 3             0  http://nyc.pediacities.com/Resource/PostalCode... -73.724004
# 4             0  http://nyc.pediacities.com/Resource/PostalCode... -73.794626
# ..          ...                                                ...        ...
# 257           0  http://nyc.pediacities.com/Resource/PostalCode... -73.962753
# 258           0  http://nyc.pediacities.com/Resource/PostalCode... -73.955329
# 259           0  http://nyc.pediacities.com/Resource/PostalCode... -73.989544
# 260           0  http://nyc.pediacities.com/Resource/PostalCode... -74.015293
# 261           0  http://nyc.pediacities.com/Resource/PostalCode... -74.015450
#
#       latitude                                           geometry
# 0    40.751662  POLYGON ((-73.86942 40.74916, -73.89143 40.746...
# 1    40.745366  POLYGON ((-73.71133 40.74947, -73.71068 40.750...
# 2    40.748714  POLYGON ((-73.70098 40.73890, -73.70309 40.744...
# 3    40.736534  POLYGON ((-73.72270 40.75373, -73.72251 40.753...
# 4    40.739903  POLYGON ((-73.81089 40.72717, -73.81116 40.728...
# ..         ...                                                ...
# 257  40.764539  POLYGON ((-73.95232 40.76454, -73.95442 40.762...
# 258  40.773149  POLYGON ((-73.94908 40.76828, -73.95052 40.768...
# 259  40.776593  POLYGON ((-73.98821 40.78123, -73.98675 40.780...
# 260  40.712377  POLYGON ((-74.01468 40.70980, -74.01638 40.710...
# 261  40.716315  POLYGON ((-74.01322 40.71832, -74.01321 40.718...
#
# [262 rows x 12 columns]

# %% [markdown]
# ### Merge covid dataframe with GeoDataFrame

# %%
geo_merge = gdf.merge(merged, right_on = 'Zip', left_on = 'postalCode')
geo_merge
# Out:
#      OBJECTID postalCode          PO_NAME STATE    borough ST_FIPS CTY_FIPS  \
# 0           1      11372  Jackson Heights    NY     Queens      36      081
# 1           2      11004        Glen Oaks    NY     Queens      36      081
# 2           4      11426        Bellerose    NY     Queens      36      081
# 3           5      11365    Fresh Meadows    NY     Queens      36      081
# 4           6      11373         Elmhurst    NY     Queens      36      081
# ..        ...        ...              ...   ...        ...     ...      ...
# 184       239      10022         New York    NY  Manhattan      36      061
# 185       258      10065         New York    NY  Manhattan      36      061
# 186       259      10075         New York    NY  Manhattan      36      061
# 187       260      10069         New York    NY  Manhattan      36      061
# 188       262      10282         New York    NY  Manhattan      36      061
#
#      BLDGpostal                                                @id  longitude  \
# 0             0  http://nyc.pediacities.com/Resource/PostalCode... -73.883573
# 1             0  http://nyc.pediacities.com/Resource/PostalCode... -73.711608
# 2             0  http://nyc.pediacities.com/Resource/PostalCode... -73.724004
# 3             0  http://nyc.pediacities.com/Resource/PostalCode... -73.794626
# 4             0  http://nyc.pediacities.com/Resource/PostalCode... -73.878423
# ..          ...                                                ...        ...
# 184           0  http://nyc.pediacities.com/Resource/PostalCode... -73.968165
# 185           0  http://nyc.pediacities.com/Resource/PostalCode... -73.962753
# 186           0  http://nyc.pediacities.com/Resource/PostalCode... -73.955329
# 187           0  http://nyc.pediacities.com/Resource/PostalCode... -73.989544
# 188           0  http://nyc.pediacities.com/Resource/PostalCode... -74.015450
#
#       latitude                                           geometry    Zip  \
# 0    40.751662  POLYGON ((-73.86942 40.74916, -73.89143 40.746...  11372
# 1    40.745366  POLYGON ((-73.71133 40.74947, -73.71068 40.750...  11004
# 2    40.736534  POLYGON ((-73.72270 40.75373, -73.72251 40.753...  11426
# 3    40.739903  POLYGON ((-73.81089 40.72717, -73.81116 40.728...  11365
# 4    40.738851  POLYGON ((-73.88722 40.72753, -73.88721 40.728...  11373
# ..         ...                                                ...    ...
# 184  40.758526  POLYGON ((-73.97255 40.76490, -73.96268 40.760...  10022
# 185  40.764539  POLYGON ((-73.95232 40.76454, -73.95442 40.762...  10065
# 186  40.773149  POLYGON ((-73.94908 40.76828, -73.95052 40.768...  10075
# 187  40.776593  POLYGON ((-73.98821 40.78123, -73.98675 40.780...  10069
# 188  40.716315  POLYGON ((-74.01322 40.71832, -74.01321 40.718...  10282
#
#      Population  Positive  TotalTested  PercentTestedPos  PercentPopTested
# 0         63202      1476         1992             74.10              3.15
# 1         14045       330          521             63.34              3.71
# 2         19348       301          537             56.05              2.78
# 3         43138       457          828             55.19              1.92
# 4        100713      1893         2647             71.51              2.63
# ..          ...       ...          ...               ...               ...
# 184       29699       222          567             39.15              1.91
# 185       31761       218          639             34.12              2.01
# 186       24377       265          571             46.41              2.34
# 187        5523        35           94             37.23              1.70
# 188        5903        48           94             51.06              1.59
#
# [189 rows x 18 columns]

# %% [markdown]
# # Plotting

# %%
fig, ax = plt.subplots(figsize = (55,40))
vmin = geo_merge['PercentPopTested'].min()
vmax = geo_merge['PercentPopTested'].max()
geo_merge.plot(ax=ax,column = 'PercentPopTested',cmap='RdBu',legend = False)
ax.set_title("Coronavirus Testing in NYC", fontdict={'fontsize': 70}, loc='center')
ax.annotate("Percent of the population within each zip code in NYC that has been tested for Covid19", xy=(0.25, .1), size=50, xycoords='figure fraction')
# plt.xlim([6,19])
# plt.ylim([36,47.7])
plt.xticks([], [])
plt.yticks([], [])

cax = fig.add_axes([.85, 0.28, 0.02, 0.5])
sm = plt.cm.ScalarMappable(cmap='RdBu', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbr = fig.colorbar(sm, cax=cax)
cbr.set_label('Percent of Zip Code Tested', size=30)
cbr.ax.tick_params(labelsize=40) 
ax.set_axis_off()
# plt.savefig('choropleth.png',format = 'png',bbox_inches='tight')
